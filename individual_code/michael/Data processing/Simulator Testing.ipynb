# %%
import pandas as pd

# %%
df = pd.read_csv('Midblock_Traffic_Counts.csv')

# %%
# Out:
#              Street        Street From    Street To
# 0  Lagimodiere Blvd         Maginot St  Dawson Rd N
# 1     Marrington Rd  Blackwood Bay (S)  Alanmore Ct
# 2     Marrington Rd  Blackwood Bay (S)  Alanmore Ct
# 3     Marrington Rd  Blackwood Bay (S)  Alanmore Ct
# 4     Marrington Rd  Blackwood Bay (S)  Alanmore Ct

# %%
df['Street'].unique()
# Out:
# array(['Lagimodiere Blvd', 'Marrington Rd', 'Bonner Ave', ...,
#        'Storie Rd', 'St Vital Park West Entrance', 'Shaughnessy St'],
#       dtype=object)

# %%
pd.set_option('display.max_rows', 2000)

# %%
df.Street.unique()
# Out:
# array(['Lagimodiere Blvd', 'Marrington Rd', 'Bonner Ave', ...,
#        'Storie Rd', 'St Vital Park West Entrance', 'Shaughnessy St'],
#       dtype=object)

# %%
df.Street.unique().size
# Out:
# 1287

# %%
df.Street.unique()
# Out:
# array(['Lagimodiere Blvd', 'Marrington Rd', 'Bonner Ave', ...,
#        'Storie Rd', 'St Vital Park West Entrance', 'Shaughnessy St'],
#       dtype=object)

# %%
prev = {'Street': None, 'Street From': None, 'Street to': None}
for index, row in df.iterrows():
    if((prev['Street'] == row['Street'] and prev['Street From'] == row['Street From']) == False):
        print(row['Street'] +", " + row['Street From'])
        prev = row
# Out:
# Lagimodiere Blvd, Maginot St
# Marrington Rd, Blackwood Bay (S)
# Marrington Rd, Alanmore Ct
# Bonner Ave, Mitchelson Way
# Gateway Rd, McLeod Ave
# Salter St, Royal Ave
# Leila Ave, Simkin Dr
# Marrington Rd, Alanmore Ct
# Maryland Bridge NB, Academy Rd
# Marrington Rd, Alanmore Ct
# Maryland Bridge NB, Academy Rd
# Marrington Rd, Alanmore Ct
# Maryland Bridge NB, Academy Rd
# Marrington Rd, Alanmore Ct
# Maryland Bridge NB, Academy Rd
# Marrington Rd, Alanmore Ct
# Maryland Bridge NB, Academy Rd
# Nairn Ave, Stadacona St
# Marrington Rd, Alanmore Ct
# Nairn Ave, Stadacona St
# Leila Ave, Simkin Dr
# Marrington Rd, Alanmore Ct
# Nairn Ave, Stadacona St
# Marrington Rd, Alanmore Ct
# Nairn Ave, Stadacona St
# Marrington Rd, Alanmore Ct
# Nairn Ave, Stadacona St
# Marrington Rd, Alanmore Ct
# Nairn Ave, Stadacona St
# Marrington Rd, Alanmore Ct
# Nairn Ave, Stadacona St
# Marrington Rd, Alanmore Ct
# Nairn Ave, Stadacona St
# Marrington Rd, Alanmore Ct
# Nairn Ave, Stadacona St
# ...

# %%
prev = {'Street': None, 'Street From': None, 'Street to': None}

# %%
print(prev['Street'])
# Out:
# None
